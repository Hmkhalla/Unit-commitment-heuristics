# %%
ratios = [0, 0.1, 0.25, 0.5]

# %%
names = ['10_24_0_w', '10_24_1_w', '20_24_0_w', '20_24_1_w', '20_24_0_w2', '50_24_0_w', '50_24_1_w', '50_24_2_w', '100_24_01_w', '150_24_012_w']
rel_obj = [
    [1.012903579,
    1.011354979,
    1.011354979,
    1.0074222],
    [None,
    1.006731768,
    1.006731768,
    1.002163781],
    [None,
    1.000640452,
    1.00002463,
    1],
    [1.002923972,
    1.002458264,
    1.002073738,
    0.9999999996],
    [None,
    1,
    1,
    1,],
    [None,
    1.000022448,
    0.9999688447,
    0.999970912],
    [1.000356118,
    1.000055427,
    1,
    0.9999857008],
    [None,
    1.000556928,
    1.00000831,
    1.000041965],
    [1.000264436,
    1.000086864,
    0.9999847545,
    0.9999537503],
    [None,
    1.00091022,
    1.000034393,
    1]
]
rel_time = [
    [0.1751145634,
    0.2790435609,
    0.2923092799,
    0.3948963282,],
    [None,
    0.3773111686,
    0.6586952258,
    0.5897258827,
    ],
    [None,
    0.8829731911,
    1.024645708,
    0.8291738169,],
    [0.2741147651,
    0.2894623884,
    0.4683680798,
    0.8322639406],
    [None,
    0.8785252987,
    1.326612169,
    1.614300383],
    [None,
    0.5375404164,
    0.5878468646,
    0.7365959295],
    [0.1558517168,
    0.206595823,
    0.527366499,
    0.5174930156],
    [None,
    0.3824175334,
    0.5505574773,
    0.6602507501],
    [0.1087743821,
    0.1980585239,
    0.07123135564,
    0.09670631036],
    [None,
    0.6208491241,
    0.5737506857,
    0.6950935428],
]

# %%
import matplotlib.pyplot as plt


fig, ax = plt.subplots(1,2, figsize=(17, 10))
ax[0].set_ylabel('Relative objective value')
ax[0].set_xlabel('ratio')
ax[0].set_title('Relative objective value w.r.t ratio')
ax[1].set_ylabel('Relative time')
ax[1].set_xlabel('ratio')
ax[1].set_title('Relative time execution w.r.t ratio')


for i in range(len(names)):
    ax[0].plot(ratios, rel_obj[i], label=names[i], marker = 'o',markersize = 10, lw = 4,mfc = 'red')
    ax[1].plot(ratios, rel_time[i], label=names[i], marker = 'o',markersize = 10, lw = 4,mfc = 'red')
for i in range(2):
    ax[i].legend(loc='upper right')
    ax[i].grid()
plt.savefig('test ratios.png')
plt.show()
